# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.0-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.3.0-py2.py3-none-any.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 kB 21.0 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.0

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(
    bootstrap_servers=['YOUR_KAFKA_IP:9092'],   # Tp replace the IP later
    value_serializer=lambda v: dumps(v).encode('utf-8')
)

# %%
producer.send(
    'demo_test',
    value={"surname": "AamirRaza"}
)

# %%
df = pd.read_csv("data/indexProcessed.csv")

# %%
# Simulating live data flow

while True:
    dict_stock = df.sample(1).to_dict(orient="records")[0]
    producer.send('demo_test', value=dict_stock)
    sleep(1)

# %%
producer.flush()
