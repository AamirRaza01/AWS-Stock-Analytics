# %%
# !mkdir -p /content/stock-market-analysis/data

# %%
# !pip install kafka-python pandas boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.3/326.3 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 110.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !pip install s3fs

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
    bootstrap_servers=['YOUR_KAFKA_IP:9092'],   # To be replace it later
    value_deserializer=lambda x: loads(x.decode('utf-8')),
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id="my-group"
)

# %%
for message in consumer:
    print(message.value)

# %%
AWS_ACCESS_KEY = ""
AWS_SECRET_KEY = ""
MY_BUCKET_NAME = ""

# %%
s3 = S3FileSystem(
    key = AWS_ACCESS_KEY,
    secret = AWS_SECRET_KEY,
)

bucket_name = MY_BUCKET_NAME

# %%
for count, i in enumerate(consumer):
    s3_path = f"s3://{bucket_name}/stock_market_{count}.json"
    with s3.open(s3_path, 'w') as file:
        json.dump(i.value, file)
    print("Uploaded →", s3_path)

# %%
# %cd /content/stock-market-analysis/
# Out:
# /content/stock-market-analysis

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/stock-market-analysis/.git/

# %%
# !git config --global user.email "itsaamirrazaofficial@gmail.com"
# !git config --global user.name "AamirRaza01"

# %%
# !git remote add origin https://github.com/AamirRaza01/AWS-Stock-Analytics.git

# %%
# !git add .

# %%
# !git commit -m "Added consumer and producer notebooks as wella as data folder"
# Out:
# [master (root-commit) 18700c0] Added consumer and producer notebooks as wella as data folder
#  2 files changed, 104352 insertions(+)
#  create mode 100644 Kafka_Producer.ipynb
#  create mode 100644 data/indexProcessed.csv

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# To https://github.com/AamirRaza01/AWS-Stock-Analytics.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/AamirRaza01/AWS-Stock-Analytics.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git fetch origin
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 877 bytes | 219.00 KiB/s, done.
# From https://github.com/AamirRaza01/AWS-Stock-Analytics
#  * [new branch]      main       -> origin/main

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/AamirRaza01/AWS-Stock-Analytics
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git push -u origin main
# Out:
# To https://github.com/AamirRaza01/AWS-Stock-Analytics.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/AamirRaza01/AWS-Stock-Analytics.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git push -u origin main --force
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 2.48 MiB | 1.42 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/AamirRaza01/AWS-Stock-Analytics.git
#  + 52d95af...18700c0 main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.
